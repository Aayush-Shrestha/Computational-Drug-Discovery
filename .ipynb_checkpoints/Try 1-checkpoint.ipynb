# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
from chembl_webresource_client.new_client import new_client
from rdkit import Chem
from skimpy import skim
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
target = new_client.target
target_query = target.search('Neuraminidase')
targets = pd.DataFrame.from_dict(target_query)

# %%
dataframes = []

# %%
for i in range(len(targets)):
    target_chembl_id = targets.target_chembl_id.iloc[i]
    target_name = targets.target_chembl_id.iloc[i]
    
    activity = new_client.activity
    activity_query = activity.filter(target_chembl_id=target_chembl_id)
    
    df = pd.DataFrame.from_dict(activity_query)
    df['target'] = target_name
    
    dataframes.append(df)

# %%
len(dataframes)
# Out:
# 73

# %%
df = pd.concat(dataframes[:40], ignore_index=True)
df.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        72419                  []
# 1        None             None        72420                  []
# 2        None             None        89474                  []
# 3        None             None       105745                  []
# 4        None             None       106883                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL808321                inhibition of Influenza A Sialidase
# 1    CHEMBL808321                inhibition of Influenza A Sialidase
# 2    CHEMBL808321                inhibition of Influenza A Sialidase
# 3    CHEMBL882330  inhibitory concentration required to inhibit n...
# 4    CHEMBL882330  inhibitory concentration required to inhibit n...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000192  ...
# 1          B                    None                   None  BAO_0000192  ...
# 2          B                    None                   None  BAO_0000192  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_pref_name target_tax_id text_value  toid  type units    uo_units  \
# 0    Neuraminidase        211044       None  None    Ki     M  UO_0000065
# 1    Neuraminidase        211044       None  None    Ki     M  UO_0000065
# 2    Neuraminidase        211044       None  None    Ki     M  UO_0000065
# 3    Neuraminidase        211044       None  None  IC50    uM  UO_0000065
# 4    Neuraminidase        211044       None  None  IC50    uM  UO_0000065
#
#    upper_value     value      target
# 0         None  0.000004  CHEMBL2051
# 1         None      1E-9  CHEMBL2051
# 2         None      4E-8  CHEMBL2051
# 3         None      40.0  CHEMBL2051
# 4         None       0.1  CHEMBL2051
#
# [5 rows x 47 columns]

# %%
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 10396  │ │ string      │ 38    │                                                          │
# │ │ Number of columns │ 44     │ │ int32       │ 6     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column_name   ┃ NA ┃ NA % ┃ mean     ┃ sd      ┃ p0    ┃ p25     ┃ p50      ┃ p75      ┃ p100     ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━┩  │
# │ │ activity_id   │  0 │    0 │ 11000000 │ 7600000 │ 72000 │ 2600000 │ 13000000 │ 18000000 │ 25000000 │ ▇▂▁▅▇▁ │  │
# │ │ document_year │  0 │    0 │     2000 │     6.7 │  2000 │    2000 │     2000 │     2000 │     2000 │ ▂▂▁▇▆▇ │  │
# │ │ potential_dup │  0 │    0 │    0.063 │    0.24 │     0 │       0 │        0 │        0 │        1 │ ▇    ▁ │  │
# │ │ licate        │    │      │          │         │       │         │          │          │          │        │  │
# │ │ record_id     │  0 │    0 │  1800000 │ 1100000 │ 23000 │  770000 │  1800000 │  3000000 │  3900000 │ ▅▃▅▃▇▁ │  │
# │ │ src_id        │  0 │    0 │      2.1 │     6.4 │     1 │       1 │        1 │        1 │       38 │   ▇    │  │
# │ │ standard_flag │  0 │    0 │     0.88 │    0.33 │     0 │       1 │        1 │        1 │        1 │ ▁    ▇ │  │
# │ └───────────────┴────┴──────┴──────────┴─────────┴───────┴─────────┴──────────┴──────────┴──────────┴────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                        ┃ NA         ┃ NA %       ┃ words per row          ┃ total words        ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ activity_comment                   │       9747 │      93.76 │                   0.11 │               1190 │  │
# │ │ assay_chembl_id                    │          0 │          0 │                      1 │              10396 │  │
# │ │ assay_description                  │          0 │          0 │                     19 │             194251 │  │
# │ │ assay_type                         │          0 │          0 │                      1 │              10396 │  │
# │ │ assay_variant_accession            │       9984 │      96.04 │                   0.04 │                412 │  │
# │ │ assay_variant_mutation             │       9984 │      96.04 │                   0.04 │                412 │  │
# │ │ bao_endpoint                       │          0 │          0 │                      1 │              10396 │  │
# │ │ bao_format                         │          0 │          0 │                      1 │              10396 │  │
# │ │ bao_label                          │          0 │          0 │                    2.8 │              29508 │  │
# │ │ canonical_smiles                   │          0 │          0 │                      1 │              10396 │  │
# │ │ data_validity_comment              │       9013 │       86.7 │                    0.4 │               4149 │  │
# │ │ data_validity_description          │       9013 │       86.7 │                    1.7 │              18011 │  │
# │ │ document_chembl_id                 │          0 │          0 │                      1 │              10396 │  │
# │ │ document_journal                   │        320 │       3.08 │                    3.2 │              33260 │  │
# │ │ molecule_chembl_id                 │          0 │          0 │                      1 │              10396 │  │
# │ │ molecule_pref_name                 │       8061 │      77.54 │                   0.29 │               2992 │  │
# │ │ parent_molecule_chembl_id          │          0 │          0 │                      1 │              10396 │  │
# │ │ pchembl_value                      │       4097 │      39.41 │                   0.61 │               6299 │  │
# │ │ qudt_units                         │        838 │       8.06 │                   0.92 │               9558 │  │
# │ │ relation                           │        641 │       6.17 │                   0.94 │               9755 │  │
# │ │ standard_relation                  │        641 │       6.17 │                   0.94 │               9755 │  │
# │ │ standard_text_value                │      10396 │        100 │                      0 │                  0 │  │
# │ │ standard_type                      │          0 │          0 │                      1 │              10796 │  │
# │ │ standard_units                     │        826 │       7.95 │                   0.92 │               9578 │  │
# │ │ standard_upper_value               │      10396 │        100 │                      0 │                  0 │  │
# │ │ standard_value                     │        641 │       6.17 │                   0.94 │               9755 │  │
# │ │ target_chembl_id                   │          0 │          0 │                      1 │              10396 │  │
# │ │ target_organism                    │          0 │          0 │                    3.7 │              38963 │  │
# │ │ target_pref_name                   │          0 │          0 │                    1.1 │              11763 │  │
# │ │ target_tax_id                      │          0 │          0 │                      1 │              10396 │  │
# │ │ text_value                         │      10396 │        100 │                      0 │                  0 │  │
# │ │ toid                               │      10396 │        100 │                      0 │                  0 │  │
# │ │ type                               │          0 │          0 │                      1 │              10846 │  │
# │ │ units                              │       1569 │      15.09 │                   0.89 │               9278 │  │
# │ │ uo_units                           │        838 │       8.06 │                   0.92 │               9558 │  │
# │ │ upper_value                        │      10389 │      99.93 │                0.00067 │                  7 │  │
# │ │ value                              │        641 │       6.17 │                   0.94 │               9755 │  │
# │ │ target                             │          0 │          0 │                      1 │              10396 │  │
# │ └────────────────────────────────────┴────────────┴────────────┴────────────────────────┴────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
df = df.drop(["upper_value","toid","text_value","standard_upper_value","standard_text_value","data_validity_description",
             "data_validity_comment","molecule_pref_name","assay_variant_mutation","assay_variant_accession",
             "activity_comment","activity_properties","action_type","ligand_efficiency"],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10396 entries, 0 to 10395
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   activity_id                10396 non-null  int64
#  1   assay_chembl_id            10396 non-null  object
#  2   assay_description          10396 non-null  object
#  3   assay_type                 10396 non-null  object
#  4   bao_endpoint               10396 non-null  object
#  5   bao_format                 10396 non-null  object
#  6   bao_label                  10396 non-null  object
#  7   canonical_smiles           10396 non-null  object
#  8   document_chembl_id         10396 non-null  object
#  9   document_journal           10076 non-null  object
#  10  document_year              10396 non-null  int64
#  11  molecule_chembl_id         10396 non-null  object
#  12  parent_molecule_chembl_id  10396 non-null  object
#  13  pchembl_value              6299 non-null   object
#  14  potential_duplicate        10396 non-null  int64
#  15  qudt_units                 9558 non-null   object
#  16  record_id                  10396 non-null  int64
#  17  relation                   9755 non-null   object
#  18  src_id                     10396 non-null  int64
#  19  standard_flag              10396 non-null  int64
#  20  standard_relation          9755 non-null   object
#  21  standard_type              10396 non-null  object
#  22  standard_units             9570 non-null   object
#  23  standard_value             9755 non-null   object
#  24  target_chembl_id           10396 non-null  object
#  25  target_organism            10396 non-null  object
#  26  target_pref_name           10396 non-null  object
#  27  target_tax_id              10396 non-null  object
#  28  type                       10396 non-null  object
#  29  units                      8827 non-null   object
#  30  uo_units                   9558 non-null   object
#  31  value                      9755 non-null   object
#  32  target                     10396 non-null  object
# dtypes: int64(6), object(27)
# memory usage: 2.6+ MB

# %%
df.isnull().sum()
# Out:
# activity_id                     0
# assay_chembl_id                 0
# assay_description               0
# assay_type                      0
# bao_endpoint                    0
# bao_format                      0
# bao_label                       0
# canonical_smiles                0
# document_chembl_id              0
# document_journal              320
# document_year                   0
# molecule_chembl_id              0
# parent_molecule_chembl_id       0
# pchembl_value                4097
# potential_duplicate             0
# qudt_units                    838
# record_id                       0
# relation                      641
# src_id                          0
# standard_flag                   0
# standard_relation             641
# standard_type                   0
# standard_units                826
# standard_value                641
# target_chembl_id                0
# target_organism                 0
# target_pref_name                0
# target_tax_id                   0
# type                            0
# units                        1569
# uo_units                      838
# value                         641
# target                          0
# dtype: int64

# %%
sns.heatmap(df.isnull(), cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
df = df.dropna()

# %%
sns.heatmap(df.isnull(), cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
numerics = ['int16', 'int32', 'int64', 'float']
numeric_df = df.select_dtypes(include = numerics)
numeric_df
# Out:
#        activity_id  document_year  potential_duplicate  record_id  src_id  \
# 0            72419           1994                    0     307604       1
# 1            72420           1994                    0     307606       1
# 2            89474           1994                    0     307605       1
# 3           105745           2000                    0     221284       1
# 4           106883           2000                    0     221285       1
# ...            ...            ...                  ...        ...     ...
# 10390     18700438           2018                    0    3105702       1
# 10391     18700439           2018                    0    3105703       1
# 10392     18700468           2018                    0    3105698       1
# 10393     18700469           2018                    0    3105699       1
# 10394     18700470           2018                    0    3105700       1
#
#        standard_flag
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 10390              1
# 10391              1
# 10392              1
# 10393              1
# 10394              1
#
# [5837 rows x 6 columns]

# %%
plt.figure(figsize=(10,10))
sns.heatmap(numeric_df.corr(), cbar = True, annot = True, cmap = 'Blues')
# Out:
# <Axes: >

# %%
pd.unique(df['units'])
# Out:
# array(['M', 'uM', 'nM', 'NM', 'microM', 'umol/L', "10'-10M",
#        "10'-4microM", "10'-8M", "10'-7M", "10'-6M", "10'-5M", "10'-9M",
#        'mM'], dtype=object)

# %%
def convert_values(row):
    try:
        value = pd.to_numeric(row['value'],errors='coerce')
    except ValueError:
        return None
    if row['units'] == 'uM' or row['units'] == 'microM' or row['units'] == 'umol/L' or row['units'] == "10'-6M":
        return value / 1000000
    elif (row['units'] == 'nM') or (row['units'] == 'NM') or (row['units'] == "10'-9M"):
        return value / 1000000000
    elif row['units'] ==  "10'-10M":
        return value / 10000000000
    elif row['units'] == "10'-4microM":
        return value / 10000000000
    elif row['units'] == "10'-8M":
        return value / 100000000
    elif row['units'] == "10'-7M":
        return value / 10000000
    elif row['units'] == "10'-5M":
        return value / 100000
    elif row['units'] == 'mM':
        return value / 1000
    else:
        return value
df['value'] = df.apply(convert_values, axis = 1)
df['units'] = 'M'
df
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18524\3464385308.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['value'] = df.apply(convert_values, axis = 1)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18524\3464385308.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['units'] = 'M'
#        activity_id assay_chembl_id  \
# 0            72419    CHEMBL808321
# 1            72420    CHEMBL808321
# 2            89474    CHEMBL808321
# 3           105745    CHEMBL882330
# 4           106883    CHEMBL882330
# ...            ...             ...
# 10390     18700438   CHEMBL4254774
# 10391     18700439   CHEMBL4254774
# 10392     18700468   CHEMBL4254779
# 10393     18700469   CHEMBL4254779
# 10394     18700470   CHEMBL4254779
#
#                                        assay_description assay_type  \
# 0                    inhibition of Influenza A Sialidase          B
# 1                    inhibition of Influenza A Sialidase          B
# 2                    inhibition of Influenza A Sialidase          B
# 3      inhibitory concentration required to inhibit n...          B
# 4      inhibitory concentration required to inhibit n...          B
# ...                                                  ...        ...
# 10390  Inhibition of Influenza A virus (A/WSN/1933(H1...          B
# 10391  Inhibition of Influenza A virus (A/WSN/1933(H1...          B
# 10392  Inhibition of Influenza A virus (A/WSN/1933(H1...          B
# 10393  Inhibition of Influenza A virus (A/WSN/1933(H1...          B
# 10394  Inhibition of Influenza A virus (A/WSN/1933(H1...          B
#
#       bao_endpoint   bao_format              bao_label  \
# 0      BAO_0000192  BAO_0000357  single protein format
# 1      BAO_0000192  BAO_0000357  single protein format
# 2      BAO_0000192  BAO_0000357  single protein format
# 3      BAO_0000190  BAO_0000357  single protein format
# 4      BAO_0000190  BAO_0000357  single protein format
# ...            ...          ...                    ...
# 10390  BAO_0000190  BAO_0000357  single protein format
# 10391  BAO_0000190  BAO_0000357  single protein format
# 10392  BAO_0000190  BAO_0000219      cell-based format
# 10393  BAO_0000190  BAO_0000219      cell-based format
# 10394  BAO_0000190  BAO_0000219      cell-based format
#
#                                         canonical_smiles document_chembl_id  \
# 0          CC(=O)NC1C(O)C=C(C(=O)O)OC1[C@H](O)[C@H](O)CO      CHEMBL1127812
# 1        CC(=O)NC1C(NC(=N)N)C=C(C(=O)O)OC1C(O)[C@H](O)CO      CHEMBL1127812
# 2          CC(=O)NC1C(N)C=C(C(=O)O)OC1[C@H](O)[C@H](O)CO      CHEMBL1127812
# 3      CC(=O)N[C@@H]([C@H](O)[C@H](O)CO)[C@H]1OC(O)(C...      CHEMBL1133646
# 4          CCCCC(NC(C)=O)[C@@H]1CC(C(=O)O)C[C@H]1N=C(N)N      CHEMBL1133646
# ...                                                  ...                ...
# 10390  CCC(CC)[C@H](NC(C)=O)[C@@H]1[C@H](OC(=O)NCCCO)...      CHEMBL4251642
# 10391  CCC(CC)[C@H](NC(C)=O)[C@@H]1[C@H](OC(=O)NCCCN)...      CHEMBL4251642
# 10392  CCC(CC)[C@H](NC(C)=O)[C@@H]1[C@H](O)[C@@H](C(=...      CHEMBL4251642
# 10393  CCC(CC)[C@H](NC(C)=O)[C@@H]1[C@H](OC(=O)NCCCOC...      CHEMBL4251642
# 10394  CCC(CC)[C@H](NC(C)=O)[C@@H]1[C@H](OC(=O)NCCCNC...      CHEMBL4251642
#
#       document_journal  ...  standard_value target_chembl_id  \
# 0           J Med Chem  ...          4000.0       CHEMBL2051
# 1           J Med Chem  ...             1.0       CHEMBL2051
# 2           J Med Chem  ...            40.0       CHEMBL2051
# 3           J Med Chem  ...         40000.0       CHEMBL2051
# 4           J Med Chem  ...           100.0       CHEMBL2051
# ...                ...  ...             ...              ...
# 10390   Eur J Med Chem  ...            0.64    CHEMBL1287610
# 10391   Eur J Med Chem  ...            0.94    CHEMBL1287610
# 10392   Eur J Med Chem  ...             0.4    CHEMBL1287610
# 10393   Eur J Med Chem  ...             0.9    CHEMBL1287610
# 10394   Eur J Med Chem  ...             1.8    CHEMBL1287610
#
#                                          target_organism target_pref_name  \
# 0         Influenza A virus (A/Puerto Rico/8/1934(H1N1))    Neuraminidase
# 1         Influenza A virus (A/Puerto Rico/8/1934(H1N1))    Neuraminidase
# 2         Influenza A virus (A/Puerto Rico/8/1934(H1N1))    Neuraminidase
# 3         Influenza A virus (A/Puerto Rico/8/1934(H1N1))    Neuraminidase
# 4         Influenza A virus (A/Puerto Rico/8/1934(H1N1))    Neuraminidase
# ...                                                  ...              ...
# 10390  Influenza A virus (strain A/Wilson-Smith/1933 ...    Neuraminidase
# 10391  Influenza A virus (strain A/Wilson-Smith/1933 ...    Neuraminidase
# 10392  Influenza A virus (strain A/Wilson-Smith/1933 ...    Neuraminidase
# 10393  Influenza A virus (strain A/Wilson-Smith/1933 ...    Neuraminidase
# 10394  Influenza A virus (strain A/Wilson-Smith/1933 ...    Neuraminidase
#
#        target_tax_id  type  units    uo_units         value         target
# 0             211044    Ki      M  UO_0000065  4.000000e-06     CHEMBL2051
# 1             211044    Ki      M  UO_0000065  1.000000e-09     CHEMBL2051
# 2             211044    Ki      M  UO_0000065  4.000000e-08     CHEMBL2051
# 3             211044  IC50      M  UO_0000065  4.000000e-51     CHEMBL2051
# 4             211044  IC50      M  UO_0000065  1.000000e-53     CHEMBL2051
# ...              ...   ...    ...         ...           ...            ...
# 10390         381518  IC50      M  UO_0000065  6.400000e-64  CHEMBL1287610
# 10391         381518  IC50      M  UO_0000065  9.400000e-64  CHEMBL1287610
# 10392         381518  IC50      M  UO_0000065  4.000000e-64  CHEMBL1287610
# 10393         381518  IC50      M  UO_0000065  9.000000e-64  CHEMBL1287610
# 10394         381518  IC50      M  UO_0000065  1.800000e-63  CHEMBL1287610
#
# [5837 rows x 33 columns]

# %%
def smiles_to_mol(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        return Chem.RDKFingerprint(mol)
    else:
        return None

# %%
df['fingerprint'] = df['canonical_smiles'].apply(smiles_to_mol)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18524\505444983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fingerprint'] = df['canonical_smiles'].apply(smiles_to_mol)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5837 entries, 0 to 10394
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   activity_id                5837 non-null   int64
#  1   assay_chembl_id            5837 non-null   object
#  2   assay_description          5837 non-null   object
#  3   assay_type                 5837 non-null   object
#  4   bao_endpoint               5837 non-null   object
#  5   bao_format                 5837 non-null   object
#  6   bao_label                  5837 non-null   object
#  7   canonical_smiles           5837 non-null   object
#  8   document_chembl_id         5837 non-null   object
#  9   document_journal           5837 non-null   object
#  10  document_year              5837 non-null   int64
#  11  molecule_chembl_id         5837 non-null   object
#  12  parent_molecule_chembl_id  5837 non-null   object
#  13  pchembl_value              5837 non-null   object
#  14  potential_duplicate        5837 non-null   int64
#  15  qudt_units                 5837 non-null   object
#  16  record_id                  5837 non-null   int64
#  17  relation                   5837 non-null   object
#  18  src_id                     5837 non-null   int64
#  19  standard_flag              5837 non-null   int64
#  20  standard_relation          5837 non-null   object
#  21  standard_type              5837 non-null   object
#  22  standard_units             5837 non-null   object
#  23  standard_value             5837 non-null   object
#  24  target_chembl_id           5837 non-null   object
#  25  target_organism            5837 non-null   object
#  26  target_pref_name           5837 non-null   object
#  27  target_tax_id              5837 non-null   object
#  28  type                       5837 non-null   object
#  29  units                      5837 non-null   object
#  30  uo_units                   5837 non-null   object
#  31  value                      5837 non-null   float64
#  32  target                     5837 non-null   object
#  33  fingerprint                5837 non-null   object
# dtypes: float64(1), int64(6), object(27)
# memory usage: 1.6+ MB
